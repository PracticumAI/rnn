# %% [markdown]
# ![Practicum AI Logo image](https://github.com/PracticumAI/practicumai.github.io/blob/main/images/logo/PracticumAI_logo_250x50.png?raw=true)
# ***
# This exercise adapted from Baig et al. (2020) <i>The Deep Learning Workshop</i> from <a href="https://www.packtpub.com/product/the-deep-learning-workshop/9781839219856">Packt Publishers</a> (Exercise 5.01, page 221).
#
# <div style="padding: 10px;margin-bottom: 20px;border: thin solid #30335D;border-left-width: 10px;background-color: #fff"><strong>Note:</strong> This exercise starts at the beginning of the Time Series Data: Stock Prediction section.</div>
#
# #### Time Series Data

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
inp0 = pd.read_csv('data/AAPL.csv')
inp0.head()
# Out:
#         Date   Close    Open     High     Low   Volume
# 0  1/17/2020  138.31  136.54  138.330  136.16  5623336
# 1  1/16/2020  137.98  137.32  138.190  137.01  4320911
# 2  1/15/2020  136.62  136.00  138.055  135.71  4045952
# 3  1/14/2020  135.82  136.28  137.139  135.55  3683458
# 4  1/13/2020  136.60  135.48  136.640  135.07  3531572

# %%
inp0.tail()
# Out:
#            Date   Close    Open     High     Low    Volume
# 2509  1/29/2010  122.39  124.32  125.000  121.90  11571890
# 2510  1/28/2010  123.75  127.03  127.040  123.05   9616132
# 2511  1/27/2010  126.33  125.82  126.960  125.04   8719147
# 2512  1/26/2010  125.75  125.92  127.750  125.41   7135190
# 2513  1/25/2010  126.12  126.33  126.895  125.71   5738455

# %% [markdown]
# #### Exercise 5.01 (Student)
#
# -------------------------------------------

# %% [markdown]
# <span style="color:steelblue">**(1)**</span>

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <span style="color:steelblue">**(2)**</span>

# %%
# Code it!

# %% [markdown]
# <span style="color:steelblue">**(3)**</span>

# %%
# Code it!

# %% [markdown]
# <span style="color:steelblue">**(4)**</span>

# %%
# Code it!

# %% [markdown]
# <span style="color:steelblue">**(5)**</span>

# %%
# Code it!

# %% [markdown]
# <span style="color:steelblue">**(6)**</span>

# %%
# Code it!

# %% [markdown]
# <div style="padding: 10px;margin-bottom: 20px;border: thin solid #30335D;border-left-width: 10px;background-color: #fff"><strong>Note:</strong> Unfortunately, there is no continuous clear trend; the prices rose for a period, after which the stock waxed and waned. The pattern isn't straightforward. We can see that there is some seasonality at a small duration (maybe monthly). Overall, the pattern is rather complex and there are no obvious and easy-to-identify cyclicities in the data that we can exploit.   </div>
